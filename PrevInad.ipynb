# %%
"""
# Se precisar baixar os dados:

import kagglehub

# Download latest version
path = kagglehub.dataset_download("miguelmallqui17/peru-student-enrollment-data-2023")

print("Path to dataset files:", path)
"""
# Out:
# '\n# Se precisar baixar os dados:\n\nimport kagglehub\n\n# Download latest version\npath = kagglehub.dataset_download("miguelmallqui17/peru-student-enrollment-data-2023")\n\nprint("Path to dataset files:", path)\n'

# %% [markdown]
# <center>UFPB - CCSA - Bacharelado em Ciência de Dados para Negócios
#
# Projeto Aplicado: Aprendizagem Supervisionada
#
# Prof. Aléssio Tony
#
# ### Predição de inadimplência estudantil em instituições de ensino superior privadas: Uma aplicação de aprendizagem de máquina supervisionada como ferramenta de gestão comercial, marketing e financeira
#
# ### Alunos:
# Beatriz Gonçalves Bento
#
# Renato Silva de Assis</center>

# %% [markdown]
# <center>Fonte dos dados: https://www.kaggle.com/datasets/miguelmallqui17/peru-student-enrollment-data-2023?select=peru_student_enrollment_data_2023.csv </center>
#
# ### Sobre o Conjunto de Dados (traduzido para do inglês, da página no Kaggle)
# Este conjunto de dados contém informações de matrículas de estudantes de uma universidade peruana para o ano de 2023. Ele apresenta desafios como valores ausentes e formatação inconsistente, particularmente na representação de gênero (1, 2, M, F, U), o que requer limpeza e transformação dos dados. O conjunto de dados permite uma análise aprofundada das tendências de matrícula, entre outros indicadores.
#
# Descrição:
#
# MATRÍCULA – Tipo de matrícula do estudante:
# - Novo: Estudante se matriculando pela primeira vez.
# - Rematriculado: Estudante dando continuidade aos estudos sem interrupção.
# - Reincorporado: Estudante retornando após um período de inatividade.
#
# CLASSIFICAÇÃO:
# - Cursos de Graduação (Carreras Pregrado)
# - Cursos de Graduação Semipresenciais (50-50)
# - Cursos de Graduação Semipresenciais (80-20)
# - Cursos de Graduação para Pessoas que Trabalham (Carreras PPE)
# - Cursos de Graduação a Distância (Carreras Pregrado Virtual)
#
# PAGAMENTO DE ANUIDADE MARÇO 2022 – Indica se o estudante pagou a mensalidade em março de 2022 (0 = Não, 1 = Sim).
#
# PAGAMENTO DE ANUIDADE MARÇO 2023 – Indica se o estudante pagou a mensalidade em março de 2023 (0 = Não, 1 = Sim).
#
# GÊNERO – Gênero do estudante (M, F, U, 1 ->(M), 2 ->(F)).
#
# PROGRAMA/CURSO – Programa acadêmico ou curso no qual o estudante está matriculado.
#
# TURNO/HORÁRIO – Horário de estudo (Manhã, Tarde, Noite, Misto).
#
# MODALIDADE DE ESTUDO – Modalidade de estudo:
#
# - Presencial: Aulas realizadas em um campus físico.
# - Online: Aulas totalmente online.
# - Remoto: Aulas online com algumas atividades presenciais.
# - A ser determinado: Modalidade de estudo ainda não selecionada.
#
# FAIXA ETÁRIA DO ESTUDANTE MATRICULADO – Faixa etária dos estudantes matriculados.
#
# DEPARTAMENTO – Departamento onde o estudante reside ou estuda.
#
# PROVÍNCIA – Província onde o estudante reside ou estuda.
#
# DISTRITO – Distrito onde o estudante reside ou estuda.
#
# TIPO DE INSTITUIÇÃO DE ENSINO – Tipo de instituição de onde o estudante vem (Escola, Instituto, etc.).
#
# STATUS DA INSTITUIÇÃO – Status da instituição (Pública ou Privada).
#
# BOLSAS DE DESCONTO – Indica se o estudante recebe algum benefício financeiro ou desconto.
#
# NÚMERO DE CURSOS MATRICULADOS – Número de cursos nos quais o estudante está matriculado.
#
# CURSO EM RISCO – Indica se o estudante tem cursos com risco de reprovação.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('peru_student_enrollment_data_2023.csv', sep=';')

def renomear_colunas(df):
  """
  Renomeia as colunas de um DataFrame pandas para a tradução em português,
  e abreviando para facilitar utilização posterior.

  Args:
    df: O DataFrame pandas a ser renomeado.

  Returns:
    Um novo DataFrame pandas com as colunas renomeadas.
  """
  nomes_em_ingles = [
      'ENROLLMENT',
      'TUITION PAYMENT MARCH 2022',
      'TUITION PAYMENT MARCH 2023',
      'GENDER',
      'TYPE OF EDUCATIONAL INSTITUTION',
      'EDUCATIONAL INSTITUTION',
      'INSTITUTION STATUS',
      'DEPARTMENT',
      'PROVINCE',
      'DISTRICT',
      'CLASSIFICATION',
      'CAMPUS',
      'FACULTY',
      'PROGRAM/MAJOR',
      'SHIFT/SCHEDULE',
      'BENEFIT DISCOUNTS',
      'STUDY MODE',
      'AGE RANGE OF ENROLLED STUDENT',
      'DISABILITY',
      'NUMBER OF ENROLLED COURSES',
      'AT-RISK COURSE'
  ]

  nomes_em_portugues = [
      'MATRICULA',
      'PGTO_ANUIDADE_2022',
      'PGTO_ANUIDADE_2023',
      'GENERO',
      'TIPO_INSTITUIÇAO_ENSINO_ORIGEM',
      'INSTITUIÇAO_ENSINO_ORIGEM',
      'STATUS_INSTITUIÇAO_ORIGEM',
      'DEPARTAMENTO',
      'PROVINCIA',
      'DISTRITO',
      'CLASSIFICACAO',
      'CAMPUS',
      'FACULDADE',
      'PROGRAMA_CURSO',
      'TURNO',
      'BOLSAS_DESCONTO',
      'MODALIDADE_ENSINO',
      'FAIXA_ETARIA',
      'DEFICIENCIA',
      'NUMERO_DISCIPLINAS_MATRICULADAS',
      'CURSO_EM_RISCO'
  ]

  dicionario_de_nomes = dict(zip(nomes_em_ingles, nomes_em_portugues))
  df_renomeado = df.rename(columns=dicionario_de_nomes)
  return df_renomeado

# %% [markdown]
# ### Tradução do nome das colunas para português

# %%
df_trad = renomear_colunas(data.copy()) # Usando .copy() para não modificar o DataFrame original inplace

# Configura para exibir todas as colunas
pd.set_option('display.max_columns', None)

df_trad
# Out:
#         MATRICULA  PGTO_ANUIDADE_2022  PGTO_ANUIDADE_2023 GENERO  \
# 0           Nuevo                   0                   0      M
# 1           Nuevo                   1                   0      M
# 2           Nuevo                   1                   1      F
# 3           Nuevo                   0                   0      F
# 4           Nuevo                   1                   1      F
# ...           ...                 ...                 ...    ...
# 37577  Reinscrito                   1                   1      F
# 37578  Reinscrito                   1                   1      F
# 37579  Reinscrito                   1                   1      F
# 37580  Reinscrito                   1                   1      M
# 37581  Reinscrito                   1                   1      F
#
#       TIPO_INSTITUIÇAO_ENSINO_ORIGEM     INSTITUIÇAO_ENSINO_ORIGEM  \
# 0                          INSTITUTO                          IDAT
# 1                            COLEGIO                  COLEGIO SISE
# 2                                NaN                           NaN
# 3                            COLEGIO         1220 SAN JOSE MARELLO
# 4                          INSTITUTO                          IDAT
# ...                              ...                           ...
# 37577                            NaN                   UNIVERSIDAD
# 37578                            NaN                           NaN
# 37579                            NaN                           NaN
# 37580                    UNIVERSIDAD  PONTIFICIAUNIVERSIDADCATÓLIC
# 37581                            NaN                           NaN
#
#       STATUS_INSTITUIÇAO_ORIGEM DEPARTAMENTO PROVINCIA  \
# 0                       PRIVADA         LIMA      LIMA
# 1                       PRIVADA         LIMA      LIMA
# 2                           NaN         LIMA      LIMA
# 3                       ESTATAL         LIMA      LIMA
# 4                       PRIVADA         LIMA      LIMA
# ...                         ...          ...       ...
# 37577                       NaN     AREQUIPA  AREQUIPA
# 37578                       NaN         LIMA      LIMA
# 37579                       NaN         LIMA      LIMA
# 37580                   PRIVADA         LIMA      LIMA
# 37581                       NaN         LIMA      LIMA
#
#                       DISTRITO              CLASSIFICACAO           CAMPUS  \
# 0                        BRENA          Carreras Pregrado  UTP Lima Centro
# 1      VILLA MARIA DEL TRIUNFO          Carreras Pregrado  UTP Lima Centro
# 2                  JESUS MARIA          Carreras Pregrado  UTP Lima Centro
# 3                          ATE    Carreras Pregrado 50-50  UTP Lima Centro
# 4                    SURQUILLO          Carreras Pregrado  UTP Lima Centro
# ...                        ...                        ...              ...
# 37577                    CAYMA  Carreras Pregrado Virtual      UTP Virtual
# 37578               LURIGANCHO  Carreras Pregrado Virtual      UTP Virtual
# 37579                     LIMA  Carreras Pregrado Virtual      UTP Virtual
# 37580               CHORRILLOS  Carreras Pregrado Virtual      UTP Virtual
# 37581                    COMAS  Carreras Pregrado Virtual      UTP Virtual
#
#                             FACULDADE                      PROGRAMA_CURSO  \
# 0            Fac. Ing. Sist. Y Elect.      ING. DE REDES Y COMUNICACIONES
# 1            Fac. Ing. Sist. Y Elect.                    ING. DE SISTEMAS
# 2      Fac. Der. Cienc. Polit. Y RRII                             DERECHO
# 3                    Fac. Adm. Y Neg.  ADMINISTRACION DE NEGOCIOS (50/50)
# 4                    Fac. Adm. Y Neg.         ADM. DE NEGOCIOS INTERNACIO
# ...                               ...                                 ...
# 37577               Fac. Hum y CC Soc                PSICOLOGIA (VIRTUAL)
# 37578               Fac. Hum y CC Soc                PSICOLOGIA (VIRTUAL)
# 37579                Fac. Adm. Y Neg.          ADM. DE EMPRESAS (VIRTUAL)
# 37580           Fac. Ing. Ind. Y Mec.           ING. INDUSTRIAL (VIRTUAL)
# 37581  Fac. Der. Cienc. Polit. Y RRII                   DERECHO (VIRTUAL)
#
#         TURNO BOLSAS_DESCONTO MODALIDADE_ENSINO FAIXA_ETARIA DEFICIENCIA  \
# 0       MIXTO   SIN BENEFICIO        Presencial      5. >=30          No
# 1       NOCHE   SIN BENEFICIO        Presencial     4. 24-29          No
# 2       NOCHE   SIN BENEFICIO        Presencial     4. 24-29          No
# 3       NOCHE   SIN BENEFICIO        Presencial     4. 24-29          No
# 4      MAÑANA       CONVENIOS        Presencial     4. 24-29          No
# ...       ...             ...               ...          ...         ...
# 37577   MIXTO   SIN BENEFICIO           Virtual      5. >=30          No
# 37578   MIXTO   SIN BENEFICIO           Virtual      5. >=30          No
# 37579   NOCHE   SIN BENEFICIO           Virtual      5. >=30          No
# 37580   MIXTO   SIN BENEFICIO           Virtual      5. >=30          No
# 37581   MIXTO   SIN BENEFICIO            Remoto      5. >=30          No
#
#        NUMERO_DISCIPLINAS_MATRICULADAS  CURSO_EM_RISCO
# 0                                    0               0
# 1                                    3               0
# 2                                    1               0
# 3                                    0               0
# 4                                    2               0
# ...                                ...             ...
# 37577                                2               0
# 37578                                3               0
# 37579                                3               0
# 37580                                3               0
# 37581                                3               0
#
# [37582 rows x 21 columns]

# %%
print("\nData info:")
df_trad.info()
# Out:
# Data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37582 entries, 0 to 37581
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   MATRICULA                        37582 non-null  object
#  1   PGTO_ANUIDADE_2022               37582 non-null  int64
#  2   PGTO_ANUIDADE_2023               37582 non-null  int64
#  3   GENERO                           37580 non-null  object
#  4   TIPO_INSTITUIÇAO_ENSINO_ORIGEM   15868 non-null  object
#  5   INSTITUIÇAO_ENSINO_ORIGEM        18212 non-null  object
#  6   STATUS_INSTITUIÇAO_ORIGEM        15868 non-null  object
#  7   DEPARTAMENTO                     36846 non-null  object
#  8   PROVINCIA                        36846 non-null  object
#  9   DISTRITO                         36846 non-null  object
#  10  CLASSIFICACAO                    37581 non-null  object
#  11  CAMPUS                           37582 non-null  object
#  12  FACULDADE                        37581 non-null  object
#  13  PROGRAMA_CURSO                   37581 non-null  object
#  14  TURNO                            37524 non-null  object
#  15  BOLSAS_DESCONTO                  37582 non-null  object
#  16  MODALIDADE_ENSINO                37582 non-null  object
#  17  FAIXA_ETARIA                     37578 non-null  object
#  18  DEFICIENCIA                      37582 non-null  object
#  19  NUMERO_DISCIPLINAS_MATRICULADAS  37582 non-null  int64
#  20  CURSO_EM_RISCO                   37582 non-null  int64
# dtypes: int64(4), object(17)
# memory usage: 6.0+ MB

# %%
# Valores faltantes:
print("\nValores faltantes:")
print(df_trad.isnull().sum())
# Out:
# Valores faltantes:
# MATRICULA                              0
# PGTO_ANUIDADE_2022                     0
# PGTO_ANUIDADE_2023                     0
# GENERO                                 2
# TIPO_INSTITUIÇAO_ENSINO_ORIGEM     21714
# INSTITUIÇAO_ENSINO_ORIGEM          19370
# STATUS_INSTITUIÇAO_ORIGEM          21714
# DEPARTAMENTO                         736
# PROVINCIA                            736
# DISTRITO                             736
# CLASSIFICACAO                          1
# CAMPUS                                 0
# FACULDADE                              1
# PROGRAMA_CURSO                         1
# TURNO                                 58
# BOLSAS_DESCONTO                        0
# MODALIDADE_ENSINO                      0
# FAIXA_ETARIA                           4
# DEFICIENCIA                            0
# NUMERO_DISCIPLINAS_MATRICULADAS        0
# CURSO_EM_RISCO                         0
# dtype: int64

# %% [markdown]
# ### Descarte de colunas

# %%
# Descartar Colunas com NaN demais e deletando linhas com NaN:
df_trad = df_trad.drop(['TIPO_INSTITUIÇAO_ENSINO_ORIGEM','INSTITUIÇAO_ENSINO_ORIGEM','STATUS_INSTITUIÇAO_ORIGEM'], axis=1).dropna()

# Descartar Colunas relativas a localização que fazem hierarquia natural com 'DEPARTAMENTO', 
df_trad = df_trad.drop(['PROVINCIA','DISTRITO'], axis=1)

# Descartar coluna 'MODALIDADE_ENSINO' por ser redundante com a coluna 'CLASSIFICACAO': 
df_trad = df_trad.drop(['MODALIDADE_ENSINO'], axis=1)

# Descartar coluna 'PROGRAMA_CURSO' por fazer hierarquia natural com 'FACULDADE': 
df_trad = df_trad.drop(['PROGRAMA_CURSO'], axis=1)

print(df_trad.isnull().sum())
# Out:
# MATRICULA                          0
# PGTO_ANUIDADE_2022                 0
# PGTO_ANUIDADE_2023                 0
# GENERO                             0
# DEPARTAMENTO                       0
# CLASSIFICACAO                      0
# CAMPUS                             0
# FACULDADE                          0
# TURNO                              0
# BOLSAS_DESCONTO                    0
# FAIXA_ETARIA                       0
# DEFICIENCIA                        0
# NUMERO_DISCIPLINAS_MATRICULADAS    0
# CURSO_EM_RISCO                     0
# dtype: int64

# %% [markdown]
# ### Tradução de valores para português

# %%
# Avaliando o problema de "GENERO":
df_trad['GENERO'].value_counts()
# Out:
# GENERO
# M    20555
# F    15892
# U      200
# 2       85
# 1       52
# Name: count, dtype: int64

# %%
df = df_trad # Backup

# Identificar valores únicos
print("\nValores únicos na coluna 'GENERO':", df['GENERO'].unique())

# Mapear correção e tradução
genero_mapping = {
    1: 'H',
    '1': 'H',
    2: 'M',
    '2': 'M',
    'M': 'H',
    'F': 'M',
    'U': 'I'
}

# Aplicar correção:
df['GENERO'] = df['GENERO'].map(genero_mapping)

# Valores únicos após correção:
print("\nValores únicos na coluna 'GENERO' após correção:", df['GENERO'].unique())
# Out:
# Valores únicos na coluna 'GENERO': ['M' 'F' 'U' '2' '1']
#
# Valores únicos na coluna 'GENERO' após correção: ['H' 'M' 'I']

# %%
# Traduzindo e ajustando variáveis:
# Dicionário com os mapeamentos por coluna
mapas = {
    'CLASSIFICACAO': {
        'Carreras Pregrado': 'Graduacao',
        'Carreras Pregrado 50-50': 'Graduacao_Semipresencial_50_50',
        'Carreras Pregrado 80-20': 'Graduacao_Semipresencial_80_20',
        'Carreras PPE': 'Curso_para_Trabalhadores',
        'Carreras Pregrado Virtual': 'Graduacao_Virtual'
    },
    'MATRICULA': {
        'Nuevo': 'Novo',
        'Reincorporado': 'Reincorporado',
        'Reinscrito': 'Reinscrito'
    },
    'DEPARTAMENTO': {
        'SAN MARTIN': 'SAN_MARTIN',
        'LA LIBERTAD': 'LA_LIBERTAD',
        'MADRE DE DIOS': 'MADRE_DE_DIOS',
        'LIMA': 'LIMA',
        'CALLAO': 'CALLAO',
        'AMAZONAS': 'AMAZONAS',
        'ICA': 'ICA',
        'AREQUIPA': 'AREQUIPA',
        'JUNIN': 'JUNIN',
        'HUANUCO': 'HUANUCO',
        'AYACUCHO': 'AYACUCHO',
        'ANCASH': 'ANCASH',
        'PASCO': 'PASCO',
        'CUSCO': 'CUSCO',
        'LAMBAYEQUE': 'LAMBAYEQUE',
        'HUANCAVELICA': 'HUANCAVELICA',
        'PIURA': 'PIURA',
        'CAJAMARCA': 'CAJAMARCA',
        'APURIMAC': 'APURIMAC',
        'PUNO': 'PUNO',
        'UCAYALI': 'UCAYALI',
        'LORETO': 'LORETO',
        'TACNA': 'TACNA',
        'MOQUEGUA': 'MOQUEGUA',
        'TUMBES': 'TUMBES'
    },
    'FAIXA_ETARIA': {
        '1. <=18': 'Menor_que_18',
        '2. 19-20': 'De_19_a_20',
        '3. 21-23': 'De_21_a_23',
        '4. 24-29': 'De_24_a_29',
        '5. >=30': 'Maior_que_30'
    },
    'BOLSAS_DESCONTO': {
        'SIN BENEFICIO': 'Sem_Beneficio',
        'CONVENIOS': 'Convenios',
        'SOCIOECONOMICA ESPECIAL - UTP': 'Bolsa_Socioecon_Especial',
        'SOCIOECONOMICA - UTP': 'Bolsa_Socioeconomica',
        'MADREDIOSENSE - UTP': 'Bolsa_MadreDeDios',
        'BECA ALTO POTENCIAL': 'Bolsa_Alto_Potencial',
        'BECA TALENTO UTP': 'Bolsa_Talento'
    },
    'TURNO': {
        'MAÑANA': 'Manha',
        'TARDE': 'Tarde',
        'NOCHE': 'Noite',
        'MIXTO': 'Misto'
    },
    'CAMPUS': {
        'UTP Lima Centro': 'Lima_Centro',
        'UTP Lima Norte': 'Lima_Norte',
        'UTP SJL': 'Lima_SJL',
        'UTP Lima Este': 'Lima_Este',
        'UTP Lima Sur': 'Lima_Sur',
        'UTP Arequipa': 'Arequipa',
        'UTP Chiclayo': 'Chiclayo',
        'UTP Piura': 'Piura',
        'UTP Chimbote': 'Chimbote',
        'UTP Huancayo': 'Huancayo',
        'UTP Ica': 'Ica',
        'UTP Beca 18': 'Beca_18',
        'UTP Trujillo': 'Trujillo',
        'UTP Virtual': 'Virtual'
    },
    'FACULDADE': {
        'Fac. Ing. Sist. Y Elect.': 'Engenharia_Sistemas_Eletrica',
        'Fac. Der. Cienc. Polit. Y RRII': 'Direito_Ciencias_Politicas',
        'Fac. Adm. Y Neg.': 'Administracao_Negocios',
        'Fac. Cienc. Com.': 'Ciencias_Comunicacao',
        'Fac. Ing. Ind. Y Mec.': 'Engenharia_Industrial_Mecanica',
        'Fac. Hum y CC Soc': 'Humanas_Ciencias_Sociais',
        'Fac. Contabilidad': 'Contabilidade',
        'Fac. Salud': 'Saude'
    }
}

# Aplicação dos mapeamentos de forma automática
for coluna, mapa in mapas.items():
    df[coluna] = df[coluna].map(mapa)

# %%
df_trad.columns
# Out:
# Index(['MATRICULA', 'PGTO_ANUIDADE_2022', 'PGTO_ANUIDADE_2023', 'GENERO',
#        'DEPARTAMENTO', 'CLASSIFICACAO', 'CAMPUS', 'FACULDADE', 'TURNO',
#        'BOLSAS_DESCONTO', 'FAIXA_ETARIA', 'DEFICIENCIA',
#        'NUMERO_DISCIPLINAS_MATRICULADAS', 'CURSO_EM_RISCO'],
#       dtype='object')

# %%
# Mostrando os valores únicos de cada coluna para que possamos analisar:

for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values in column '{column}':")
    print(unique_values)
    print("-" * 30)
# Out:
# Unique values in column 'MATRICULA':
# ['Novo' 'Reincorporado' 'Reinscrito']
# ------------------------------
# Unique values in column 'PGTO_ANUIDADE_2022':
# [0 1]
# ------------------------------
# Unique values in column 'PGTO_ANUIDADE_2023':
# [0 1]
# ------------------------------
# Unique values in column 'GENERO':
# ['H' 'M' 'I']
# ------------------------------
# Unique values in column 'DEPARTAMENTO':
# ['LIMA' 'CALLAO' 'AMAZONAS' 'ICA' 'AREQUIPA' 'SAN_MARTIN' 'JUNIN'
#  'LA_LIBERTAD' 'HUANUCO' 'AYACUCHO' 'ANCASH' 'PASCO' 'CUSCO' 'LAMBAYEQUE'
#  'HUANCAVELICA' 'PIURA' 'CAJAMARCA' 'APURIMAC' 'PUNO' 'UCAYALI'
#  'MADRE_DE_DIOS' 'LORETO' 'TACNA' 'MOQUEGUA' 'TUMBES']
# ------------------------------
# Unique values in column 'CLASSIFICACAO':
# ['Graduacao' 'Graduacao_Semipresencial_50_50'
#  'Graduacao_Semipresencial_80_20' 'Curso_para_Trabalhadores'
#  'Graduacao_Virtual']
# ------------------------------
# Unique values in column 'CAMPUS':
# ['Lima_Centro' 'Lima_Norte' 'Lima_SJL' 'Lima_Este' 'Lima_Sur' 'Arequipa'
#  'Chiclayo' 'Piura' 'Chimbote' 'Huancayo' 'Ica' 'Beca_18' 'Trujillo'
#  'Virtual']
# ------------------------------
# Unique values in column 'FACULDADE':
# ['Engenharia_Sistemas_Eletrica' 'Direito_Ciencias_Politicas'
#  'Administracao_Negocios' 'Ciencias_Comunicacao'
#  'Engenharia_Industrial_Mecanica' 'Humanas_Ciencias_Sociais'
#  'Contabilidade' 'Saude']
# ------------------------------
# Unique values in column 'TURNO':
# ['Misto' 'Noite' 'Manha' 'Tarde']
# ------------------------------
# Unique values in column 'BOLSAS_DESCONTO':
# ['Sem_Beneficio' 'Convenios' 'Bolsa_Socioecon_Especial'
#  'Bolsa_Socioeconomica' 'Bolsa_MadreDeDios' 'Bolsa_Alto_Potencial'
#  'Bolsa_Talento']
# ------------------------------
# Unique values in column 'FAIXA_ETARIA':
# ['Maior_que_30' 'De_24_a_29' 'De_21_a_23' 'De_19_a_20' 'Menor_que_18']
# ------------------------------
# Unique values in column 'DEFICIENCIA':
# ['No' 'Si']
# ------------------------------
# Unique values in column 'NUMERO_DISCIPLINAS_MATRICULADAS':
# [0 3 1 2 4 5 6]
# ------------------------------
# Unique values in column 'CURSO_EM_RISCO':
# [0 2 1 3 5 4]
# ------------------------------

# %%
to_dummy_cols = [
    'MATRICULA', 'GENERO', 'DEPARTAMENTO', 'CLASSIFICACAO', 
    'CAMPUS', 'FACULDADE', 'TURNO', 'BOLSAS_DESCONTO', 
    'FAIXA_ETARIA']

# Lidar com variáveis categóricas que precisam ser convertidas para dummy
df = pd.get_dummies(df, columns = to_dummy_cols, 
                                    drop_first=True)

# %%
# Converte explicitamente as colunas dummy para o tipo inteiro (em vez de booleano)
for col in df.columns:
    if df[col].dtype == 'bool':
        df[col] = df[col].astype(int)

# %%
# Converte a coluna dummy "DEFICIENCIA" de valores string para inteiro:
for index, row in df.iterrows():
    if row['DEFICIENCIA'] == 'Si':
        df.loc[index, 'DEFICIENCIA'] = 1
    elif row['DEFICIENCIA'] == 'No':
        df.loc[index, 'DEFICIENCIA'] = 0

# %% [markdown]
# ### Normalizando variáveis numéricas

# %%
# Normalização de variáveis numéricas (não binárias)
stats = []

for col in ['CURSO_EM_RISCO','NUMERO_DISCIPLINAS_MATRICULADAS']:
    # Min-Max
    stats.append({col: [df[col].min(), df[col].max()]})
    df[col] = (df[col] - df[col].min())/(df[col].max()-df[col].min())

# %%
stats
# Out:
# [{'CURSO_EM_RISCO': [np.int64(0), np.int64(5)]},
#  {'NUMERO_DISCIPLINAS_MATRICULADAS': [np.int64(0), np.int64(6)]}]

# %%
df.describe()
# Out:
#        PGTO_ANUIDADE_2022  PGTO_ANUIDADE_2023  \
# count        36784.000000        36784.000000
# mean             0.862712            0.842567
# std              0.344156            0.364213
# min              0.000000            0.000000
# 25%              1.000000            1.000000
# 50%              1.000000            1.000000
# 75%              1.000000            1.000000
# max              1.000000            1.000000
#
#        NUMERO_DISCIPLINAS_MATRICULADAS  CURSO_EM_RISCO  \
# count                     36784.000000    36784.000000
# mean                          0.324358        0.029758
# std                           0.164205        0.102550
# min                           0.000000        0.000000
# 25%                           0.166667        0.000000
# 50%                           0.333333        0.000000
# 75%                           0.500000        0.000000
# max                           1.000000        1.000000
#
#        MATRICULA_Reincorporado  MATRICULA_Reinscrito      GENERO_I  \
# count             36784.000000          36784.000000  36784.000000
# mean                  0.046814              0.919449      0.005437
# std                   0.211243              0.272149      0.073537
# min                   0.000000              0.000000      0.000000
# 25%                   0.000000              1.000000      0.000000
# 50%                   0.000000              1.000000      0.000000
# 75%                   0.000000              1.000000      0.000000
# max                   1.000000              1.000000      1.000000
#
#            GENERO_M  DEPARTAMENTO_ANCASH  DEPARTAMENTO_APURIMAC  \
# count  36784.000000         36784.000000           36784.000000
# mean       0.434346             0.027023               0.002284
# std        0.495678             0.162152               0.047733
# min        0.000000             0.000000               0.000000
# 25%        0.000000             0.000000               0.000000
# 50%        0.000000             0.000000               0.000000
# 75%        1.000000             0.000000               0.000000
# max        1.000000             1.000000               1.000000
#
#        DEPARTAMENTO_AREQUIPA  DEPARTAMENTO_AYACUCHO  DEPARTAMENTO_CAJAMARCA  \
# count           36784.000000           36784.000000            36784.000000
# mean                0.167247               0.004948                0.005682
# std                 0.373201               0.070167                0.075164
# min                 0.000000               0.000000                0.000000
# 25%                 0.000000               0.000000                0.000000
# 50%                 0.000000               0.000000                0.000000
# 75%                 0.000000               0.000000                0.000000
# max                 1.000000               1.000000                1.000000
#
#        DEPARTAMENTO_CALLAO  DEPARTAMENTO_CUSCO  DEPARTAMENTO_HUANCAVELICA  \
# count         36784.000000        36784.000000               36784.000000
# mean              0.035042            0.005519                   0.001223
# std               0.183890            0.074084                   0.034956
# min               0.000000            0.000000                   0.000000
# 25%               0.000000            0.000000                   0.000000
# 50%               0.000000            0.000000                   0.000000
# 75%               0.000000            0.000000                   0.000000
# max               1.000000            1.000000                   1.000000
#
#        DEPARTAMENTO_HUANUCO  DEPARTAMENTO_ICA  DEPARTAMENTO_JUNIN  \
# count          36784.000000      36784.000000        36784.000000
# mean               0.000843          0.046433            0.024440
# std                0.029018          0.210424            0.154413
# min                0.000000          0.000000            0.000000
# 25%                0.000000          0.000000            0.000000
# 50%                0.000000          0.000000            0.000000
# 75%                0.000000          0.000000            0.000000
# max                1.000000          1.000000            1.000000
#
#        DEPARTAMENTO_LAMBAYEQUE  DEPARTAMENTO_LA_LIBERTAD  DEPARTAMENTO_LIMA  \
# count             36784.000000              36784.000000       36784.000000
# mean                  0.064920                  0.003425           0.546243
# std                   0.246387                  0.058427           0.497864
# min                   0.000000                  0.000000           0.000000
# 25%                   0.000000                  0.000000           0.000000
# 50%                   0.000000                  0.000000           1.000000
# 75%                   0.000000                  0.000000           1.000000
# max                   1.000000                  1.000000           1.000000
#
#        DEPARTAMENTO_LORETO  DEPARTAMENTO_MADRE_DE_DIOS  DEPARTAMENTO_MOQUEGUA  \
# count         36784.000000                36784.000000           36784.000000
# mean              0.001169                    0.000870               0.006389
# std               0.034171                    0.029482               0.079674
# min               0.000000                    0.000000               0.000000
# 25%               0.000000                    0.000000               0.000000
# 50%               0.000000                    0.000000               0.000000
# 75%               0.000000                    0.000000               0.000000
# max               1.000000                    1.000000               1.000000
#
#        DEPARTAMENTO_PASCO  DEPARTAMENTO_PIURA  DEPARTAMENTO_PUNO  \
# count        36784.000000        36784.000000       36784.000000
# mean             0.001903            0.035341           0.009760
# std              0.043582            0.184644           0.098309
# min              0.000000            0.000000           0.000000
# 25%              0.000000            0.000000           0.000000
# 50%              0.000000            0.000000           0.000000
# 75%              0.000000            0.000000           0.000000
# max              1.000000            1.000000           1.000000
#
#        DEPARTAMENTO_SAN_MARTIN  DEPARTAMENTO_TACNA  DEPARTAMENTO_TUMBES  \
# count             36784.000000        36784.000000         36784.000000
# mean                  0.001332            0.002555             0.001060
# std                   0.036474            0.050488             0.032545
# min                   0.000000            0.000000             0.000000
# 25%                   0.000000            0.000000             0.000000
# 50%                   0.000000            0.000000             0.000000
# 75%                   0.000000            0.000000             0.000000
# max                   1.000000            1.000000             1.000000
#
#        DEPARTAMENTO_UCAYALI  CLASSIFICACAO_Graduacao  \
# count          36784.000000             36784.000000
# mean               0.001577                 0.436277
# std                0.039678                 0.495929
# min                0.000000                 0.000000
# 25%                0.000000                 0.000000
# 50%                0.000000                 0.000000
# 75%                0.000000                 1.000000
# max                1.000000                 1.000000
#
#        CLASSIFICACAO_Graduacao_Semipresencial_50_50  \
# count                                  36784.000000
# mean                                       0.187908
# std                                        0.390644
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        CLASSIFICACAO_Graduacao_Semipresencial_80_20  \
# count                                  36784.000000
# mean                                       0.129377
# std                                        0.335621
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        CLASSIFICACAO_Graduacao_Virtual  CAMPUS_Beca_18  CAMPUS_Chiclayo  \
# count                     36784.000000    36784.000000     36784.000000
# mean                          0.150691        0.000217         0.064022
# std                           0.357752        0.014746         0.244796
# min                           0.000000        0.000000         0.000000
# 25%                           0.000000        0.000000         0.000000
# 50%                           0.000000        0.000000         0.000000
# 75%                           0.000000        0.000000         0.000000
# max                           1.000000        1.000000         1.000000
#
#        CAMPUS_Chimbote  CAMPUS_Huancayo    CAMPUS_Ica  CAMPUS_Lima_Centro  \
# count     36784.000000     36784.000000  36784.000000        36784.000000
# mean          0.023081         0.021341      0.038631            0.217649
# std           0.150162         0.144520      0.192716            0.412653
# min           0.000000         0.000000      0.000000            0.000000
# 25%           0.000000         0.000000      0.000000            0.000000
# 50%           0.000000         0.000000      0.000000            0.000000
# 75%           0.000000         0.000000      0.000000            0.000000
# max           1.000000         1.000000      1.000000            1.000000
#
#        CAMPUS_Lima_Este  CAMPUS_Lima_Norte  CAMPUS_Lima_SJL  CAMPUS_Lima_Sur  \
# count      36784.000000       36784.000000     36784.000000     36784.000000
# mean           0.057742           0.105481         0.037788         0.088979
# std            0.233259           0.307176         0.190686         0.284717
# min            0.000000           0.000000         0.000000         0.000000
# 25%            0.000000           0.000000         0.000000         0.000000
# 50%            0.000000           0.000000         0.000000         0.000000
# 75%            0.000000           0.000000         0.000000         0.000000
# max            1.000000           1.000000         1.000000         1.000000
#
#        CAMPUS_Piura  CAMPUS_Trujillo  CAMPUS_Virtual  \
# count  36784.000000     36784.000000    36784.000000
# mean       0.029660         0.001359        0.150691
# std        0.169649         0.036844        0.357752
# min        0.000000         0.000000        0.000000
# 25%        0.000000         0.000000        0.000000
# 50%        0.000000         0.000000        0.000000
# 75%        0.000000         0.000000        0.000000
# max        1.000000         1.000000        1.000000
#
#        FACULDADE_Ciencias_Comunicacao  FACULDADE_Contabilidade  \
# count                    36784.000000             36784.000000
# mean                         0.020335                 0.062989
# std                          0.141145                 0.242947
# min                          0.000000                 0.000000
# 25%                          0.000000                 0.000000
# 50%                          0.000000                 0.000000
# 75%                          0.000000                 0.000000
# max                          1.000000                 1.000000
#
#        FACULDADE_Direito_Ciencias_Politicas  \
# count                          36784.000000
# mean                               0.146504
# std                                0.353615
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
#        FACULDADE_Engenharia_Industrial_Mecanica  \
# count                              36784.000000
# mean                                   0.335988
# std                                    0.472341
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    1.000000
# max                                    1.000000
#
#        FACULDADE_Engenharia_Sistemas_Eletrica  \
# count                            36784.000000
# mean                                 0.170427
# std                                  0.376013
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        FACULDADE_Humanas_Ciencias_Sociais  FACULDADE_Saude   TURNO_Misto  \
# count                        36784.000000     36784.000000  36784.000000
# mean                             0.096237         0.011826      0.393622
# std                              0.294921         0.108103      0.488559
# min                              0.000000         0.000000      0.000000
# 25%                              0.000000         0.000000      0.000000
# 50%                              0.000000         0.000000      0.000000
# 75%                              0.000000         0.000000      1.000000
# max                              1.000000         1.000000      1.000000
#
#         TURNO_Noite   TURNO_Tarde  BOLSAS_DESCONTO_Bolsa_MadreDeDios  \
# count  36784.000000  36784.000000                       36784.000000
# mean       0.393432      0.000517                           0.000027
# std        0.488518      0.022722                           0.005214
# min        0.000000      0.000000                           0.000000
# 25%        0.000000      0.000000                           0.000000
# 50%        0.000000      0.000000                           0.000000
# 75%        1.000000      0.000000                           0.000000
# max        1.000000      1.000000                           1.000000
#
#        BOLSAS_DESCONTO_Bolsa_Socioecon_Especial  \
# count                              36784.000000
# mean                                   0.000217
# std                                    0.014746
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    1.000000
#
#        BOLSAS_DESCONTO_Bolsa_Socioeconomica  BOLSAS_DESCONTO_Bolsa_Talento  \
# count                          36784.000000                   36784.000000
# mean                               0.004921                       0.000054
# std                                0.069975                       0.007374
# min                                0.000000                       0.000000
# 25%                                0.000000                       0.000000
# 50%                                0.000000                       0.000000
# 75%                                0.000000                       0.000000
# max                                1.000000                       1.000000
#
#        BOLSAS_DESCONTO_Convenios  BOLSAS_DESCONTO_Sem_Beneficio  \
# count               36784.000000                   36784.000000
# mean                    0.012478                       0.981568
# std                     0.111008                       0.134509
# min                     0.000000                       0.000000
# 25%                     0.000000                       1.000000
# 50%                     0.000000                       1.000000
# 75%                     0.000000                       1.000000
# max                     1.000000                       1.000000
#
#        FAIXA_ETARIA_De_21_a_23  FAIXA_ETARIA_De_24_a_29  \
# count             36784.000000             36784.000000
# mean                  0.219552                 0.250517
# std                   0.413949                 0.433316
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 1.000000
# max                   1.000000                 1.000000
#
#        FAIXA_ETARIA_Maior_que_30  FAIXA_ETARIA_Menor_que_18
# count               36784.000000               36784.000000
# mean                    0.210200                   0.153735
# std                     0.407456                   0.360700
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   0.000000
# max                     1.000000                   1.000000

# %% [markdown]
# ### Dividindo dados de treino e dados de teste

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
import pickle

var_interesse = 'PGTO_ANUIDADE_2023'

# Separate features (X) and target (y)
X = df.drop(var_interesse, axis=1)
y = df[var_interesse]

# %%
models = {
    'Logit': LogisticRegression(),
    'NB': GaussianNB(),
    'KNN': KNeighborsClassifier(),
    'Tree': DecisionTreeClassifier(),
    'Forest': RandomForestClassifier()
}

# %% [markdown]
# ### Treinando o modelo

# %%
# Verificar o balanceamento da distribuição da variável alvo ('PAGAMENTO DE ANUIDADE MARÇO 2023')
print("\nDistribuição de PAGAMENTO DE ANUIDADE MARÇO 2023:")
print(df[var_interesse].value_counts(), df[var_interesse].value_counts(normalize=True))
sns.countplot(x=var_interesse, data=df)
plt.title('Distribuição de PAGAMENTO DE ANUIDADE MARÇO 2023')
plt.show()
# Out:
# Distribuição de PAGAMENTO DE ANUIDADE MARÇO 2023:
# PGTO_ANUIDADE_2023
# 1    30993
# 0     5791
# Name: count, dtype: int64 PGTO_ANUIDADE_2023
# 1    0.842567
# 0    0.157433
# Name: proportion, dtype: float64

# %%
results = {}
# Validação cruzada
for name, model in models.items():
    scores = cross_val_score(model, X, y, cv=5, scoring='f1') # Utilizando a métrica F1 pelo desbalanceamento observado acima
    results[name] = {
        'model': model,
        'mean_f1': scores.mean(),
        'std_1': scores.std()
    }

# %%
results
# Out:
# {'Logit': {'model': LogisticRegression(),
#   'mean_f1': np.float64(0.9537813284445397),
#   'std_1': np.float64(0.0686865679304043)},
#  'NB': {'model': GaussianNB(),
#   'mean_f1': np.float64(0.5003981022879205),
#   'std_1': np.float64(0.34735676377496816)},
#  'KNN': {'model': KNeighborsClassifier(),
#   'mean_f1': np.float64(0.9213799651673369),
#   'std_1': np.float64(0.04231612063251564)},
#  'Tree': {'model': DecisionTreeClassifier(),
#   'mean_f1': np.float64(0.9295191006627226),
#   'std_1': np.float64(0.07060834838301278)},
#  'Forest': {'model': RandomForestClassifier(),
#   'mean_f1': np.float64(0.9392340620942585),
#   'std_1': np.float64(0.07722019574066676)}}

# %% [markdown]
# #### O melhor modelo:

# %%
# Best Model
best_model_name = max(results, key=lambda name: results[name]['mean_f1'])
print(best_model_name)
best_model = results[best_model_name]['model']
best_model
# Out:
# Logit
# LogisticRegression()

# %%
# Estimar o modelo para todos os dados
best_model.fit(X,y)
# Out:
# LogisticRegression()

# %%
r = {
    'metodo': best_model_name,
    'resultados': best_model,
    'escala': stats,
    'f1': best_model.score(X, y)
}

# %% [markdown]
# ### Salvando o modelo em pickle

# %%
import os

save_dir = "data"
filename = os.path.join(save_dir, 'modelo_final.pkl')

# %%
pickle.dump(r, open(filename, "wb"))

# %% [markdown]
# ### Matriz de confusão

# %%
# gráfico para a matriz

y_predict = best_model.predict(X)
import pandas as pd
from sklearn.metrics import confusion_matrix
pd.DataFrame(
    confusion_matrix(y, y_predict),
    columns=[
        "Predição Inadimplente 2023",
        "Predição Pago 2023",
    ],
    index=["Inadimplente 2023 Verdadeiro", "Pago 2023 Verdadeiro"],
)
# Out:
#                               Predição Inadimplente 2023  Predição Pago 2023
# Inadimplente 2023 Verdadeiro                        5052                 739
# Pago 2023 Verdadeiro                                   1               30992

# %% [markdown]
# Seleção e treino de modelo

# %%
# Para ver todos coeficientes da célula abaixo, descomentar a linha seguinte: 
pd.set_option('display.max_rows', None) 

# Para desfazer a linha anterior:
# pd.reset_option('display.max_rows') # Optional: Reset to default after printing

# %%
# Checking up for coefficients:
coefficients = best_model.coef_[0]
feature_names = X.columns 

# Create a DataFrame to display coefficients with feature names
coefficients_df = pd.DataFrame({'Variável': feature_names, 'Coeficiente': coefficients})
coefficients_df = coefficients_df.sort_values(by='Coeficiente', ascending=False)
print("Coeficiente de Regressão Logística:")
print(coefficients_df)
# Out:
# Coeficiente de Regressão Logística:
#                                         Variável  Coeficiente
# 0                             PGTO_ANUIDADE_2022     9.942193
# 5                           MATRICULA_Reinscrito     1.387089
# 13                           DEPARTAMENTO_CALLAO     0.603687
# 31                          DEPARTAMENTO_UCAYALI     0.535399
# 39                               CAMPUS_Huancayo     0.497517
# 7                                       GENERO_M     0.397153
# 2                NUMERO_DISCIPLINAS_MATRICULADAS     0.393518
# 19                       DEPARTAMENTO_LAMBAYEQUE     0.311343
# 55                               FACULDADE_Saude     0.299921
# 21                             DEPARTAMENTO_LIMA     0.289616
# 4                        MATRICULA_Reincorporado     0.263454
# 49                FACULDADE_Ciencias_Comunicacao     0.259039
# 17                              DEPARTAMENTO_ICA     0.213642
# 23                    DEPARTAMENTO_MADRE_DE_DIOS     0.210950
# 12                        DEPARTAMENTO_CAJAMARCA     0.205861
# 25                            DEPARTAMENTO_PASCO     0.170477
# 50                       FACULDADE_Contabilidade     0.115752
# 58                                   TURNO_Tarde     0.110822
# 41                            CAMPUS_Lima_Centro     0.102171
# 32                       CLASSIFICACAO_Graduacao     0.085730
# 51          FACULDADE_Direito_Ciencias_Politicas     0.083550
# 10                         DEPARTAMENTO_AREQUIPA     0.073014
# 54            FACULDADE_Humanas_Ciencias_Sociais     0.030718
# 14                            DEPARTAMENTO_CUSCO     0.021553
# 56                                   TURNO_Misto     0.021362
# 65                       FAIXA_ETARIA_De_21_a_23     0.002042
# 59             BOLSAS_DESCONTO_Bolsa_MadreDeDios     0.000557
# 57                                   TURNO_Noite    -0.000982
# 52      FACULDADE_Engenharia_Industrial_Mecanica    -0.005098
# 30                           DEPARTAMENTO_TUMBES    -0.009009
# 36                                CAMPUS_Beca_18    -0.009863
# 60      BOLSAS_DESCONTO_Bolsa_Socioecon_Especial    -0.015568
# 33  CLASSIFICACAO_Graduacao_Semipresencial_50_50    -0.019109
# 53        FACULDADE_Engenharia_Sistemas_Eletrica    -0.019995
# 6                                       GENERO_I    -0.034228
# 62                 BOLSAS_DESCONTO_Bolsa_Talento    -0.043064
# 45                               CAMPUS_Lima_Sur    -0.082235
# 20                      DEPARTAMENTO_LA_LIBERTAD    -0.096336
# 66                       FAIXA_ETARIA_De_24_a_29    -0.099056
# 28                       DEPARTAMENTO_SAN_MARTIN    -0.108935
# 38                               CAMPUS_Chimbote    -0.119222
# 46                                  CAMPUS_Piura    -0.123620
# 8                            DEPARTAMENTO_ANCASH    -0.148420
# 16                          DEPARTAMENTO_HUANUCO    -0.166374
# 22                           DEPARTAMENTO_LORETO    -0.169218
# 67                     FAIXA_ETARIA_Maior_que_30    -0.198606
# 37                               CAMPUS_Chiclayo    -0.199912
# 26                            DEPARTAMENTO_PIURA    -0.201847
# 29                            DEPARTAMENTO_TACNA    -0.246473
# 68                     FAIXA_ETARIA_Menor_que_18    -0.252165
# 42                              CAMPUS_Lima_Este    -0.257349
# 40                                    CAMPUS_Ica    -0.280769
# 35               CLASSIFICACAO_Graduacao_Virtual    -0.285506
# 48                                CAMPUS_Virtual    -0.285506
# 11                         DEPARTAMENTO_AYACUCHO    -0.328256
# 44                               CAMPUS_Lima_SJL    -0.332887
# 43                             CAMPUS_Lima_Norte    -0.335746
# 61          BOLSAS_DESCONTO_Bolsa_Socioeconomica    -0.338182
# 27                             DEPARTAMENTO_PUNO    -0.390259
# 34  CLASSIFICACAO_Graduacao_Semipresencial_80_20    -0.445854
# 24                         DEPARTAMENTO_MOQUEGUA    -0.554361
# 47                               CAMPUS_Trujillo    -0.689299
# 63                     BOLSAS_DESCONTO_Convenios    -0.839367
# 1                                    DEFICIENCIA    -0.966349
# 9                          DEPARTAMENTO_APURIMAC    -1.102084
# 18                            DEPARTAMENTO_JUNIN    -1.222696
# 15                     DEPARTAMENTO_HUANCAVELICA    -1.269559
# 64                 BOLSAS_DESCONTO_Sem_Beneficio    -1.798964
# 3                                 CURSO_EM_RISCO    -2.907199

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
coefficients_df.to_excel('coeficientes.xlsx')

# %%
# Obter intercepto
intercept = best_model.intercept_[0]
print(f"\nIntercepto de de Regressão Logística: {intercept:.4f}")
# Out:
# Intercepto de de Regressão Logística: -5.7368
